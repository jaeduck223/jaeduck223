# %% [markdown]
# <a href="https://colab.research.google.com/github/jaeduck223/jaeduck223/blob/main/%EB%B9%85%EB%8D%B0%EC%9D%B4%ED%84%B0%EB%B6%84%EC%84%9D_%EC%88%98%EC%97%85_%EC%8B%A4%EC%8A%B5(2%EC%A3%BC%EC%B0%A8_2%EA%B0%95).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame([[1.4, np.nan], [7.1, -4.5],
                  [np.nan, np.nan], [0.75,-1.3]],
                 index=['a','b','c','d'],
                 columns=['one','two'])
df
# Out:
#     one  two
# a  1.40  NaN
# b  7.10 -4.5
# c   NaN  NaN
# d  0.75 -1.3

# %%
df.sum()
# Out:
# one    9.25
# two   -5.80
# dtype: float64

# %%
df.sum(axis='columns')
# Out:
# a    1.40
# b    2.60
# c    0.00
# d   -0.55
# dtype: float64

# %%
df.mean(axis='columns')
# Out:
# a    1.400
# b    1.300
# c      NaN
# d   -0.275
# dtype: float64

# %%
#'skipna'옵션을 사용해서 NaN을 제외할지 결정
df.mean(axis='columns', skipna=False)
# Out:
# a      NaN
# b    1.300
# c      NaN
# d   -0.275
# dtype: float64

# %%
df.idxmax()
# Out:
# one    b
# two    d
# dtype: object

# %%
df.idxmin(axis='columns')
# Out:
# <ipython-input-8-843ccf0f438a>:1: FutureWarning: The behavior of DataFrame.idxmin with all-NA values, or any-NA and skipna=False, is deprecated. In a future version this will raise ValueError
#   df.idxmin(axis='columns')
# a    one
# b    two
# c    NaN
# d    two
# dtype: object

# %%
df
# Out:
#     one  two
# a  1.40  NaN
# b  7.10 -4.5
# c   NaN  NaN
# d  0.75 -1.3

# %%
#누적(accumulation) 합
df.cumsum()
# Out:
#     one  two
# a  1.40  NaN
# b  8.50 -4.5
# c   NaN  NaN
# d  9.25 -5.8

# %%
#여러개의 통계 결과를 출력
df.describe()
# Out:
#             one       two
# count  3.000000  2.000000
# mean   3.083333 -2.900000
# std    3.493685  2.262742
# min    0.750000 -4.500000
# 25%    1.075000 -3.700000
# 50%    1.400000 -2.900000
# 75%    4.250000 -2.100000
# max    7.100000 -1.300000

# %%
# !pip install pandas-datareader

# %%
price = pd.read_pickle("yahoo_price.pkl")
volume = pd.read_pickle("yahoo_volume.pkl")

# %%
price
# Out:
#                   AAPL        GOOG         IBM       MSFT
# Date
# 2010-01-04   27.990226  313.062468  113.304536  25.884104
# 2010-01-05   28.038618  311.683844  111.935822  25.892466
# 2010-01-06   27.592626  303.826685  111.208683  25.733566
# 2010-01-07   27.541619  296.753749  110.823732  25.465944
# 2010-01-08   27.724725  300.709808  111.935822  25.641571
# ...                ...         ...         ...        ...
# 2016-10-17  117.550003  779.960022  154.770004  57.220001
# 2016-10-18  117.470001  795.260010  150.720001  57.660000
# 2016-10-19  117.120003  801.500000  151.259995  57.529999
# 2016-10-20  117.059998  796.969971  151.520004  57.250000
# 2016-10-21  116.599998  799.369995  149.630005  59.660000
#
# [1714 rows x 4 columns]

# %%
volume
# Out:
#                  AAPL      GOOG       IBM      MSFT
# Date
# 2010-01-04  123432400   3927000   6155300  38409100
# 2010-01-05  150476200   6031900   6841400  49749600
# 2010-01-06  138040000   7987100   5605300  58182400
# 2010-01-07  119282800  12876600   5840600  50559700
# 2010-01-08  111902700   9483900   4197200  51197400
# ...               ...       ...       ...       ...
# 2016-10-17   23624900   1089500   5890400  23830000
# 2016-10-18   24553500   1995600  12770600  19149500
# 2016-10-19   20034600    116600   4632900  22878400
# 2016-10-20   24125800   1734200   4023100  49455600
# 2016-10-21   22384800   1260500   4401900  79974200
#
# [1714 rows x 4 columns]

# %%
returns = price.pct_change()

# %%
returns
# Out:
#                 AAPL      GOOG       IBM      MSFT
# Date
# 2010-01-04       NaN       NaN       NaN       NaN
# 2010-01-05  0.001729 -0.004404 -0.012080  0.000323
# 2010-01-06 -0.015906 -0.025209 -0.006496 -0.006137
# 2010-01-07 -0.001849 -0.023280 -0.003462 -0.010400
# 2010-01-08  0.006648  0.013331  0.010035  0.006897
# ...              ...       ...       ...       ...
# 2016-10-17 -0.000680  0.001837  0.002072 -0.003483
# 2016-10-18 -0.000681  0.019616 -0.026168  0.007690
# 2016-10-19 -0.002979  0.007846  0.003583 -0.002255
# 2016-10-20 -0.000512 -0.005652  0.001719 -0.004867
# 2016-10-21 -0.003930  0.003011 -0.012474  0.042096
#
# [1714 rows x 4 columns]

# %%
returns.tail(10)
# Out:
#                 AAPL      GOOG       IBM      MSFT
# Date
# 2016-10-10  0.017447  0.014011  0.008672  0.004152
# 2016-10-11  0.002154 -0.003652 -0.014202 -0.014645
# 2016-10-12  0.008942  0.003920 -0.003230 -0.001399
# 2016-10-13 -0.003068 -0.010113 -0.003694 -0.003327
# 2016-10-14  0.005556  0.000437  0.004749  0.008784
# 2016-10-17 -0.000680  0.001837  0.002072 -0.003483
# 2016-10-18 -0.000681  0.019616 -0.026168  0.007690
# 2016-10-19 -0.002979  0.007846  0.003583 -0.002255
# 2016-10-20 -0.000512 -0.005652  0.001719 -0.004867
# 2016-10-21 -0.003930  0.003011 -0.012474  0.042096

# %%
returns.head(10)
# Out:
#                 AAPL      GOOG       IBM      MSFT
# Date
# 2010-01-04       NaN       NaN       NaN       NaN
# 2010-01-05  0.001729 -0.004404 -0.012080  0.000323
# 2010-01-06 -0.015906 -0.025209 -0.006496 -0.006137
# 2010-01-07 -0.001849 -0.023280 -0.003462 -0.010400
# 2010-01-08  0.006648  0.013331  0.010035  0.006897
# 2010-01-11 -0.008822 -0.001512 -0.010470 -0.012720
# 2010-01-12 -0.011375 -0.017684  0.007955 -0.006607
# 2010-01-13  0.014106 -0.005741 -0.002145  0.009312
# 2010-01-14 -0.005792  0.004701  0.015972  0.020099
# 2010-01-15 -0.016712 -0.016699 -0.004006 -0.003230

# %%
returns['MSFT'].corr(returns['IBM'])
# Out:
# 0.49976361144151144

# %%
returns['MSFT'].corr(returns['MSFT'])
# Out:
# 1.0

# %%
returns['MSFT'].cov(returns['IBM'])
# Out:
# 8.870655479703546e-05

# %%
returns['MSFT'].cov(returns['MSFT'])
# Out:
# 0.0002151170575399877

# %%
returns.corrwith(returns.IBM) #다른 Series나 DataFrame과의 상관관계를 계산한다.
# Out:
# AAPL    0.386817
# GOOG    0.405099
# IBM     1.000000
# MSFT    0.499764
# dtype: float64

# %%
obj = pd.Series(['c', 'a', 'd', 'a', 'a', 'b', 'b', 'c', 'c'])
obj
# Out:
# 0    c
# 1    a
# 2    d
# 3    a
# 4    a
# 5    b
# 6    b
# 7    c
# 8    c
# dtype: object

# %%
uniques = obj.unique()  #중복되는 값을 제거하고, 유리한 값만 담고있는 Series를 반환한다.
uniques
# Out:
# array(['c', 'a', 'd', 'b'], dtype=object)

# %%
obj.value_counts()  #Series에서 도수(frequency)를 내림차순으로 정령하여 계산한다.
# Out:
# c    3
# a    3
# b    2
# d    1
# Name: count, dtype: int64

# %%
obj.value_counts(sort=False)
# Out:
# c    3
# a    3
# d    1
# b    2
# Name: count, dtype: int64

# %%
pd.value_counts(obj.values, sort=False)
# Out:
# <ipython-input-31-e257afe01fc8>:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pd.value_counts(obj.values, sort=False)
# c    3
# a    3
# d    1
# b    2
# Name: count, dtype: int64

# %%
import numpy as np
import pandas as pd

names_1=['Hisila', 'Brian','Zeppy']
salary_1=[23,30,21]

names_2=['Ram','Shyam',"Hari"]
salary_2=[22,23,31]

df_1 = pd.DataFrame({'Name': names_1, 'Salary': salary_1})
df_2 = pd.DataFrame({'Name': names_2, 'Salary': salary_2})

# %%
df_1
# Out:
#      Name  Salary
# 0  Hisila      23
# 1   Brian      30
# 2   Zeppy      21

# %%
df_2
# Out:
#     Name  Salary
# 0    Ram      22
# 1  Shyam      23
# 2   Hari      31

# %%
merged_df = pd.concat([df_1, df_2])   #이어 붙이는 거..!(지난 버전하고 다름.)
merged_df
# Out:
#      Name  Salary
# 0  Hisila      23
# 1   Brian      30
# 2   Zeppy      21
# 0     Ram      22
# 1   Shyam      23
# 2    Hari      31

# %%
merged_df.drop([1])
# Out:
#      Name  Salary
# 0  Hisila      23
# 2   Zeppy      21
# 0     Ram      22
# 2    Hari      31

# %%
merged_df.drop(['Name'], axis=1)
# Out:
#    Salary
# 0      23
# 1      30
# 2      21
# 0      22
# 1      23
# 2      31

# %%
df = pd.DataFrame({'A':[7,1,5,4,2,1,4,4,8],'B':[1,2,8,5,3,4,2,6,8]})
df['A'].unique()
# Out:
# array([7, 1, 5, 4, 2, 8])

# %%
df['B'].unique()
# Out:
# array([1, 2, 8, 5, 3, 4, 6])

# %%
import numpy as np
import pandas as pd

fruits = pd.DataFrame({'name':['apple','mango','banana','cherry'],

                    'price':[2000,150,500,400],

                    'qty':[5,4,10, np.NaN]})

# %%
fruits
# Out:
#      name  price   qty
# 0   apple   2000   5.0
# 1   mango    150   4.0
# 2  banana    500  10.0
# 3  cherry    400   NaN

# %%
fruits.dtypes #데이터 타입
# Out:
# name      object
# price      int64
# qty      float64
# dtype: object

# %%
fruits.index = fruits['name']

# %%
fruits
# Out:
#           name  price   qty
# name
# apple    apple   2000   5.0
# mango    mango    150   4.0
# banana  banana    500  10.0
# cherry  cherry    400   NaN

# %%
fruits.iloc[:,1:3]
# Out:
#         price   qty
# name
# apple    2000   5.0
# mango     150   4.0
# banana    500  10.0
# cherry    400   NaN

# %%
fruits.mean(axis='qty')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in _get_axis_number(cls, axis)
#     575         try:
# --> 576             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     577         except KeyError:
#
# KeyError: 'qty'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-e41d9c2b3713> in <cell line: 0>()
# ----> 1 fruits.mean(axis='qty')
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in mean(self, axis, skipna, numeric_only, **kwargs)
#   11691         **kwargs,
#   11692     ):
# > 11693         result = super().mean(axis, skipna, numeric_only, **kwargs)
#   11694         if isinstance(result, Series):
#   11695             result = result.__finalize__(self, method="mean")
#
# ...

# %%
import numpy as np
import pandas as pd

fruits = pd.DataFrame({'name':['apple','mango','banana','cherry'],

                    'price':[2000,150,500,400],

                    'qty':[5,4,10, np.NaN]})

# %%
fruits
# Out:
#      name  price   qty
# 0   apple   2000   5.0
# 1   mango    150   4.0
# 2  banana    500  10.0
# 3  cherry    400   NaN

# %%
fruits.describe()
# Out:
#             price        qty
# count     4.00000   3.000000
# mean    762.50000   6.333333
# std     838.02844   3.214550
# min     150.00000   4.000000
# 25%     337.50000   4.500000
# 50%     450.00000   5.000000
# 75%     875.00000   7.500000
# max    2000.00000  10.000000

# %%
fruits['qty'].mean()  #해답 1
# Out:
# 6.333333333333333

# %%
fruits.qty.mean()     #해답 2
# Out:
# 6.333333333333333

# %%
fruits[fruits['price'] >=1000] # 해답
# Out:
#     name  price  qty
# 0  apple   2000  5.0

# %%
fruits.reindex(['cherry', 'banana', 'mango', 'apple']) #해답
# Out:
#        name  price  qty
# cherry  NaN    NaN  NaN
# banana  NaN    NaN  NaN
# mango   NaN    NaN  NaN
# apple   NaN    NaN  NaN

# %%
fruits
# Out:
#      name  price   qty
# 0   apple   2000   5.0
# 1   mango    150   4.0
# 2  banana    500  10.0
# 3  cherry    400   NaN

# %%
fruits.reindex(['cherry', 'banana', 'mango', 'apple']) #해답
# Out:
#        name  price  qty
# cherry  NaN    NaN  NaN
# banana  NaN    NaN  NaN
# mango   NaN    NaN  NaN
# apple   NaN    NaN  NaN

# %%
import numpy as np
import pandas as pd

fruits = pd.DataFrame({'name':['apple','mango','banana','cherry'],

                    'price':[2000,150,500,400],

                    'qty':[5,4,10, np.NaN]})

# %%
fruits
# Out:
#      name  price   qty
# 0   apple   2000   5.0
# 1   mango    150   4.0
# 2  banana    500  10.0
# 3  cherry    400   NaN

# %%
fruits = fruits.reindex(['apple', 'mango','peach', 'banana', 'cherry'])
fruits
# Out:
#        name  price  qty
# apple   NaN    NaN  NaN
# mango   NaN    NaN  NaN
# peach   NaN    NaN  NaN
# banana  NaN    NaN  NaN
# cherry  NaN    NaN  NaN

# %%
fruits.iloc[2,1] = 2500
fruits.iloc[2,2] = 3
fruits  # 해답
# Out:
#        name   price  qty
# apple   NaN     NaN  NaN
# mango   NaN     NaN  NaN
# peach   NaN  2500.0  3.0
# banana  NaN     NaN  NaN
# cherry  NaN     NaN  NaN

# %%
list_col = list(fruits.columns)  # 해답

# %%
list_col
# Out:
# ['name', 'price', 'qty']

# %%
list_col[2] = 'QTY'

# %%
fruits.columns = list_col

# %%
fruits
# Out:
#        name   price  QTY
# apple   NaN     NaN  NaN
# mango   NaN     NaN  NaN
# peach   NaN  2500.0  3.0
# banana  NaN     NaN  NaN
# cherry  NaN     NaN  NaN

# %%
import numpy as np
import pandas as pd

data = pd.DataFrame({'월별':['1월', '2월','3월', '4월','5월','6월','7월','8월','9월','10월','11월','12월'],
                    '콜레라':['6.0', '5.0', '1.0', '1.0', '1.0', '3.0', '14.0', np.NaN, '3.0', '1.0', '3.0', '4.0'],
                    '장티푸스':['175.0', '165.0', '200.0', '200.0', '194.0', '227.0', '179.0', '163.0', np.NaN, '107.0', '97.0', '121.0'],
                    '이질':['550', '253', np.NaN, '507', '343', '272', '224', '347', '105', '142', '377', '1,079'],
                    '대장균':['7.0', '9.0', '13.0', np.NaN, '27.0', '92.0', '201.0', '114.0', '43.0', '39.0', '27.0', '21.0'],
                    'A형간염':['351', '535', '1,003', '856', '959', '928', '630', '505', '364', '230', '190', np.NaN]})
data
# Out:
#      월별   콜레라   장티푸스     이질    대장균   A형간염
# 0    1월   6.0  175.0    550    7.0    351
# 1    2월   5.0  165.0    253    9.0    535
# 2    3월   1.0  200.0    NaN   13.0  1,003
# 3    4월   1.0  200.0    507    NaN    856
# 4    5월   1.0  194.0    343   27.0    959
# 5    6월   3.0  227.0    272   92.0    928
# 6    7월  14.0  179.0    224  201.0    630
# 7    8월   NaN  163.0    347  114.0    505
# 8    9월   3.0    NaN    105   43.0    364
# 9   10월   1.0  107.0    142   39.0    230
# 10  11월   3.0   97.0    377   27.0    190
# 11  12월   4.0  121.0  1,079   21.0    NaN

# %%
data.index = data['월별']
data
# Out:
#       월별   콜레라   장티푸스     이질    대장균   A형간염
# 월별
# 1월    1월   6.0  175.0    550    7.0    351
# 2월    2월   5.0  165.0    253    9.0    535
# 3월    3월   1.0  200.0    NaN   13.0  1,003
# 4월    4월   1.0  200.0    507    NaN    856
# 5월    5월   1.0  194.0    343   27.0    959
# 6월    6월   3.0  227.0    272   92.0    928
# 7월    7월  14.0  179.0    224  201.0    630
# 8월    8월   NaN  163.0    347  114.0    505
# 9월    9월   3.0    NaN    105   43.0    364
# 10월  10월   1.0  107.0    142   39.0    230
# 11월  11월   3.0   97.0    377   27.0    190
# 12월  12월   4.0  121.0  1,079   21.0    NaN

# %%
data = data.drop('월별', axis = 1) # 월별 컬럼을 row name으로 설정,  data = data.set_index('월별')
data
# Out:
#       콜레라   장티푸스     이질    대장균   A형간염
# 월별
# 1월    6.0  175.0    550    7.0    351
# 2월    5.0  165.0    253    9.0    535
# 3월    1.0  200.0    NaN   13.0  1,003
# 4월    1.0  200.0    507    NaN    856
# 5월    1.0  194.0    343   27.0    959
# 6월    3.0  227.0    272   92.0    928
# 7월   14.0  179.0    224  201.0    630
# 8월    NaN  163.0    347  114.0    505
# 9월    3.0    NaN    105   43.0    364
# 10월   1.0  107.0    142   39.0    230
# 11월   3.0   97.0    377   27.0    190
# 12월   4.0  121.0  1,079   21.0    NaN

# %%
data.columns.name = '병명'
data
# Out:
# 병명    콜레라   장티푸스     이질    대장균   A형간염
# 월별
# 1월    6.0  175.0    550    7.0    351
# 2월    5.0  165.0    253    9.0    535
# 3월    1.0  200.0    NaN   13.0  1,003
# 4월    1.0  200.0    507    NaN    856
# 5월    1.0  194.0    343   27.0    959
# 6월    3.0  227.0    272   92.0    928
# 7월   14.0  179.0    224  201.0    630
# 8월    NaN  163.0    347  114.0    505
# 9월    3.0    NaN    105   43.0    364
# 10월   1.0  107.0    142   39.0    230
# 11월   3.0   97.0    377   27.0    190
# 12월   4.0  121.0  1,079   21.0    NaN

# %%
data = data.fillna(0)    # NA값을 0으로 치환
data
# Out:
# 병명    콜레라   장티푸스     이질    대장균   A형간염
# 월별
# 1월    6.0  175.0    550    7.0    351
# 2월    5.0  165.0    253    9.0    535
# 3월    1.0  200.0      0   13.0  1,003
# 4월    1.0  200.0    507      0    856
# 5월    1.0  194.0    343   27.0    959
# 6월    3.0  227.0    272   92.0    928
# 7월   14.0  179.0    224  201.0    630
# 8월      0  163.0    347  114.0    505
# 9월    3.0      0    105   43.0    364
# 10월   1.0  107.0    142   39.0    230
# 11월   3.0   97.0    377   27.0    190
# 12월   4.0  121.0  1,079   21.0      0

# %%
f1 = lambda x : int(float(str(x).replace(',','')))    # 천 단위 구분기호 치환
data
# Out:
# 병명    콜레라   장티푸스     이질    대장균   A형간염
# 월별
# 1월    6.0  175.0    550    7.0    351
# 2월    5.0  165.0    253    9.0    535
# 3월    1.0  200.0      0   13.0  1,003
# 4월    1.0  200.0    507      0    856
# 5월    1.0  194.0    343   27.0    959
# 6월    3.0  227.0    272   92.0    928
# 7월   14.0  179.0    224  201.0    630
# 8월      0  163.0    347  114.0    505
# 9월    3.0      0    105   43.0    364
# 10월   1.0  107.0    142   39.0    230
# 11월   3.0   97.0    377   27.0    190
# 12월   4.0  121.0  1,079   21.0      0

# %%
data = data.map(f1)
data
# Out:
# 병명   콜레라  장티푸스    이질  대장균  A형간염
# 월별
# 1월     6   175   550    7   351
# 2월     5   165   253    9   535
# 3월     1   200     0   13  1003
# 4월     1   200   507    0   856
# 5월     1   194   343   27   959
# 6월     3   227   272   92   928
# 7월    14   179   224  201   630
# 8월     0   163   347  114   505
# 9월     3     0   105   43   364
# 10월    1   107   142   39   230
# 11월    3    97   377   27   190
# 12월    4   121  1079   21     0

# %%
data.describe()
# Out:
# 병명           콜레라        장티푸스           이질         대장균         A형간염
# count  12.000000   12.000000    12.000000   12.000000    12.000000
# mean    3.500000  152.333333   349.916667   49.416667   545.916667
# std     3.777926   62.274077   278.638723   58.871908   333.869451
# min     0.000000    0.000000     0.000000    0.000000     0.000000
# 25%     1.000000  117.500000   203.500000   12.000000   320.750000
# 50%     3.000000  170.000000   307.500000   27.000000   520.000000
# 75%     4.250000  195.500000   409.500000   55.250000   874.000000
# max    14.000000  227.000000  1079.000000  201.000000  1003.000000

# %%
data.idxmax()
# Out:
# 병명
# 콜레라      7월
# 장티푸스     6월
# 이질      12월
# 대장균      7월
# A형간염     3월
# dtype: object

# %%
data.sum()
# Out:
# 병명
# 콜레라       42
# 장티푸스    1828
# 이질      4199
# 대장균      593
# A형간염    6551
# dtype: int64

# %%
data.rank(method='first')
# Out:
# 병명    콜레라  장티푸스    이질   대장균  A형간염
# 월별
# 1월   11.0   7.0  11.0   2.0   4.0
# 2월   10.0   6.0   5.0   3.0   7.0
# 3월    2.0  10.0   1.0   4.0  12.0
# 4월    3.0  11.0  10.0   1.0   9.0
# 5월    4.0   9.0   7.0   6.0  11.0
# 6월    6.0  12.0   6.0  10.0  10.0
# 7월   12.0   8.0   4.0  12.0   8.0
# 8월    1.0   5.0   8.0  11.0   6.0
# 9월    7.0   1.0   2.0   9.0   5.0
# 10월   5.0   3.0   3.0   8.0   3.0
# 11월   8.0   2.0   9.0   7.0   2.0
# 12월   9.0   4.0  12.0   5.0   1.0

# %%
data['대장균'].idxmax() #1 해답
# Out:
# '7월'

# %%
data.sort_values(by='A형간염')  #2 해답
# Out:
# 병명   콜레라  장티푸스    이질  대장균  A형간염
# 월별
# 12월    4   121  1079   21     0
# 11월    3    97   377   27   190
# 10월    1   107   142   39   230
# 1월     6   175   550    7   351
# 9월     3     0   105   43   364
# 8월     0   163   347  114   505
# 2월     5   165   253    9   535
# 7월    14   179   224  201   630
# 4월     1   200   507    0   856
# 6월     3   227   272   92   928
# 5월     1   194   343   27   959
# 3월     1   200     0   13  1003

# %%
data['콜레라'].rank()  #3 해답
# Out:
# 월별
# 1월     11.0
# 2월     10.0
# 3월      3.5
# 4월      3.5
# 5월      3.5
# 6월      7.0
# 7월     12.0
# 8월      1.0
# 9월      7.0
# 10월     3.5
# 11월     7.0
# 12월     9.0
# Name: 콜레라, dtype: float64

# %%
data.sum(axis=0)  #4 해답
# Out:
# 병명
# 콜레라       42
# 장티푸스    1828
# 이질      4199
# 대장균      593
# A형간염    6551
# dtype: int64

# %%
data.index = data['월별']
data = data.drop('월별', axis = 1)

data.columns.name = '병명'
data = data.fillna(0)

f1 = lambda x : int(float(str(x).replace(',','')))
data = data.map(f1)  #5장에서 가장 중요한 것!!!!!!!!!
